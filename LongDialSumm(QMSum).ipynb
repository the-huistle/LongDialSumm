# %%
import torch
torch.cuda.is_available()    # GPU 사용 가능 확인
# Out:
# True

# %% [markdown]
# 출처: https://github.com/chatc/LongDialSumm
#
# - 데이터셋: QMSum

# %%
# !git clone https://github.com/chatc/LongDialSumm.git
# Out:
# fatal: 대상 경로가('LongDialSumm') 이미 있고 빈 디렉터리가 아닙니다.

# %%
# !git clone https://github.com/pytorch/fairseq
# %cd fairseq
# !pip install --editable ./
# Out:
# fatal: 대상 경로가('fairseq') 이미 있고 빈 디렉터리가 아닙니다.
# /home/dilab/SEHUI/fairseq
# Obtaining file:///home/dilab/SEHUI/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached omegaconf-2.0.6-py3-none-any.whl (36 kB)
# ...
#   Using cached Cython-0.29.28-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#   Using cached sacrebleu-2.0.0-py3-none-any.whl (90 kB)
# ...
#   Using cached bitarray-2.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (229 kB)
# ...
#   Using cached hydra_core-1.0.7-py3-none-any.whl (123 kB)
# ...
#   Using cached antlr4_python3_runtime-4.8-py3-none-any.whl
# ...
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# ...
#   Using cached portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# ...

# %%
# !pip install fairseq
# !pip install nltk
# !pip install rouge
# !pip install sklearn
# Out:
# ...
#      |████████████████████████████████| 96 kB 448 kB/s eta 0:00:01
# ...
#   Using cached rouge-1.0.1-py3-none-any.whl (13 kB)
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#   Using cached tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
# ...
#      |████████████████████████████████| 1.0 MB 343 kB/s eta 0:00:01
# ...

# %%
# !pwd
# Out:
# /home/dilab/SEHUI

# %%
# %cd ..
# Out:
# /home/dilab/SEHUI

# %%
# !chmod +x ./LongDialSumm/run.sh
# !sh ./LongDialSumm/run.sh
# Out:
# --2022-04-07 19:38:22--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/encoder.json
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# 접속 dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... 접속됨.
# HTTP 요청을 전송했습니다. 응답을 기다리는 중입니다... 304 Not Modified
# `encoder.json' 파일이 서버에서 변경되지 않았습니다. 다운로드를 누락합니다.
#
# --2022-04-07 19:38:23--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/vocab.bpe
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# 접속 dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... 접속됨.
# HTTP 요청을 전송했습니다. 응답을 기다리는 중입니다... 304 Not Modified
# `vocab.bpe' 파일이 서버에서 변경되지 않았습니다. 다운로드를 누락합니다.
#
# --2022-04-07 19:38:23--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# ...

# %%
# !bash ./LongDialSumm/run.sh
# Out:
# --2022-04-07 19:42:42--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/encoder.json
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# 접속 dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... 접속됨.
# HTTP 요청을 전송했습니다. 응답을 기다리는 중입니다... 304 Not Modified
# `encoder.json' 파일이 서버에서 변경되지 않았습니다. 다운로드를 누락합니다.
#
# --2022-04-07 19:42:44--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/vocab.bpe
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# 접속 dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... 접속됨.
# HTTP 요청을 전송했습니다. 응답을 기다리는 중입니다... 304 Not Modified
# `vocab.bpe' 파일이 서버에서 변경되지 않았습니다. 다운로드를 누락합니다.
#
# --2022-04-07 19:42:44--  https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/dict.txt
# dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)을(를) 해석하는 중... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# ...

# %%
# !python ./LongDialSumm/inference.py
# Out:
# input: ./LongDialSumm/QMSum/test.source
# output: ./LongDialSumm/QMSum/test_bart_cnn.hypo
# 2022-04-07 23:11:34 | INFO | fairseq.file_utils | loading archive file checkpoints/
# 2022-04-07 23:11:34 | INFO | fairseq.file_utils | loading archive file /home/dilab/SEHUI/LongDialSumm/EXP/QMSum-bin
# 2022-04-07 23:11:36 | INFO | fairseq.tasks.translation | [source] dictionary: 50264 types
# 2022-04-07 23:11:36 | INFO | fairseq.tasks.translation | [target] dictionary: 50264 types
# 2022-04-07 23:11:43 | INFO | fairseq.file_utils | https://dl.fbaipublicfiles.com/fairseq/gpt2_bpe/encoder.json not found in cache, downloading to /tmp/tmppg00f7qz
# 1042301B [00:00, 2436517.98B/s]
# 2022-04-07 23:11:44 | INFO | fairseq.file_utils | copying /tmp/tmppg00f7qz to cache at /home/dilab/.cache/torch/pytorch_fairseq/e2aab4d600e7568c2d88fc7732130ccc815ea84ec63906cb0913c7a3a4906a2e.0f323dfaed92d080380e63f0291d0f31adfa8c61a62cbcb3cb8114f061be27f7
# ...
